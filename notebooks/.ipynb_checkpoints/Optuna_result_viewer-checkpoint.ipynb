# %%
import optuna
import numpy as np
import os, pdb

LOG_DIR = '/raid6/ebihara/tensorflow/logs/TANDEMAUS/dblogs/'

study_name = 'offset2.0_alpha_tuning'
study_name = 'offset1.0_alpha_tuning'

storage_name = 'sqlite:///{}.db'.format(study_name)

# %%
# for upgrading .db file
# error: RuntimeError: The runtime optuna version 3.0.0 is no longer compatible with the table schema (set up by optuna 2.10.1). Please execute `$ optuna storage upgrade --storage $STORAGE_URL` for upgrading the storage.

#  !cp /raid6/ebihara/tensorflow/logs/UCF2class/dblogs/Tfmr_UCF2class_tuning.db /raid6/ebihara/tensorflow/logs/UCF2class/dblogs/Tfmr_UCF2class_tuning_orig.db
# !optuna storage upgrade --storage /raid6/ebihara/tensorflow/logs/UCF2class/dblogs/Tfmr_UCF2class_tuning.db
# !pip install optuna==2.10.1

# %%
if not os.path.exists(LOG_DIR + study_name + '.db'):
    raise ValueError('No .db file exists...double check yr paths!')

# %%
currdir = os.getcwd()
os.chdir(LOG_DIR)

study = optuna.create_study(study_name=study_name,
                            storage=storage_name,
                            load_if_exists=True)
df = study.trials_dataframe()
print('df', df)
print('best_value:', study.best_value)
print('best_params:', study.best_params)
print('best_trial:', study.best_trial)
#    print('all trials:', study.trials)
print('')

valuepos = 1
trials = study.trials
values = []
for s in trials:
    s = str(s).split()
    if not 'value' in s[valuepos]:
        raise ValueError('unexpected string structure!')
    if 'None' in s[valuepos]:
        values.append(1.0)
    else:
        # pdb.set_trace()
        #values.append(float(s[valuepos][6:-1]))
        values.append(float(s[valuepos][8:-2]))

list1, list2 = zip(*sorted(zip(values, list(trials)), reverse=True))
print('\ntotal: {}trias'.format(len(list2)))
print('above: best trials, the later the better..')
for i in range(len(list2)):
    print(list2[i])
# Out:
# [I 2022-09-13 20:25:36,968] Using an existing study with name 'Tfmr_SiW_order9_tuning' instead of creating a new one.
# df     number     value             datetime_start          datetime_complete  \
# 0        0  0.001512 2022-09-05 06:37:50.954302 2022-09-05 10:42:15.906304
# 1        1  0.001514 2022-09-05 10:42:16.024151 2022-09-05 11:58:29.479146
# 2        2  0.001552 2022-09-05 11:58:29.569132 2022-09-05 15:49:11.123145
# 3        3  0.001544 2022-09-05 15:49:11.208603 2022-09-05 19:52:55.744350
# 4        4  0.001442 2022-09-05 19:52:55.838767 2022-09-05 21:13:09.481348
# 5        5  0.001507 2022-09-05 21:13:09.567508 2022-09-06 01:07:59.499268
# 6        6  0.001503 2022-09-06 01:07:59.599198 2022-09-06 05:16:08.271764
# 7        7  0.001655 2022-09-06 05:16:08.363042 2022-09-06 09:21:49.631820
# 8        8  0.001510 2022-09-06 09:21:49.716929 2022-09-06 13:10:19.308288
# 9        9  0.001514 2022-09-06 13:10:19.447850 2022-09-06 14:14:38.409016
# 10      10  0.001499 2022-09-06 14:14:38.500811 2022-09-06 15:32:50.473486
# 23             16                32  ...               0.00010
# 24             16                32  ...               0.00010
# 25             16                32  ...               0.00001
# 26             32                32  ...               0.00010
# 27             16                32  ...               0.00010
# 28             16                32  ...               0.00010
# 29             32                32  ...               0.00001
# 30             16                32  ...               0.00010
# 31             16                32  ...               0.00010
# 32             16                32  ...               0.00010
# 33             16                32  ...               0.00010
# 34             16                32  ...               0.00100
# 35             16                32  ...               0.00010
# 36             32                32  ...               0.00100
# 37             16                32  ...               0.00010
# 38             16                32  ...               0.00100
# 39             32                32  ...               0.00010
# 40             16                32  ...               0.00010
#
#     params_mlp_activation  params_mlp_units params_num_heads  \
# 0                 B2Bsqrt                32                1
# 1                    relu                16                3
# 2                 B2Bsqrt                32                2
# 3                 B2Bsqrt                32                1
# 4                 B2Bsqrt                32                3
# 5                 B2Bsqrt                32                3
# 6                 B2Bsqrt                16                2
# 7                 B2Bsqrt                32                3
# 8                 B2Bsqrt                16                3
# 9                    relu                32                3
# 10                   relu                32                1
# 11                   relu                32                1
# 12                   relu                32                1
# 13                   relu                32                1
# 14                   relu                32                2
# 15                   relu                16                1
# 16                B2Bsqrt                32                3
# 17                B2Bsqrt                32                3
# 18                B2Bsqrt                16                3
# 19                B2Bsqrt                32                3
# 20                B2Bsqrt                32                3
# 21                   relu                32                3
# 22                B2Bsqrt                32                1
# 23                   relu                32                2
# 24                B2Bsqrt                32                3
# 25                B2Bsqrt                32                3
# 26                B2Bsqrt                16                3
# 27                B2Bsqrt                32                3
# 28                B2Bsqrt                32                3
# 29                B2Bsqrt                32                3
# 30                B2Bsqrt                32                3
# 31                B2Bsqrt                32                3
# 32                B2Bsqrt                32                3
# 33                B2Bsqrt                32                3
# 34                B2Bsqrt                32                3
# 35                B2Bsqrt                32                2
# 36                B2Bsqrt                16                3
# 37                B2Bsqrt                32                3
# 38                B2Bsqrt                32                2
# 39                B2Bsqrt                16                3
# 40                B2Bsqrt                32                3
#
#     params_num_transformer_blocks  params_optimizer  params_order_sprt  \
# 0                               1           rmsprop                  9
# 1                               1           rmsprop                  9
# 2                               1           rmsprop                  9
# 3                               1           rmsprop                  9
# 4                               1           rmsprop                  9
# 5                               1           rmsprop                  9
# 6                               1              adam                  9
# 7                               1              adam                  9
# 8                               1           rmsprop                  9
# 9                               1              adam                  9
# 10                              1           rmsprop                  9
# 11                              1           rmsprop                  9
# 12                              1           rmsprop                  9
# 13                              1           rmsprop                  9
# 14                              1           rmsprop                  9
# 15                              1              adam                  9
# 16                              1           rmsprop                  9
# 17                              1           rmsprop                  9
# 18                              1              adam                  9
# 19                              1           rmsprop                  9
# 20                              1           rmsprop                  9
# 21                              1           rmsprop                  9
# 22                              1           rmsprop                  9
# 23                              1           rmsprop                  9
# 24                              1           rmsprop                  9
# 25                              1           rmsprop                  9
# 26                              1              adam                  9
# 27                              1           rmsprop                  9
# 28                              1           rmsprop                  9
# 29                              1           rmsprop                  9
# 30                              1           rmsprop                  9
# 31                              1           rmsprop                  9
# 32                              1           rmsprop                  9
# 33                              1           rmsprop                  9
# 34                              1           rmsprop                  9
# 35                              1           rmsprop                  9
# 36                              1           rmsprop                  9
# 37                              1           rmsprop                  9
# 38                              1              adam                  9
# 39                              1           rmsprop                  9
# 40                              1           rmsprop                  9
#
#    params_param_llr_loss  params_weight_decay     state
# 0                    1.0              0.00000  COMPLETE
# 1                    1.0              0.00001  COMPLETE
# 2                    1.0              0.00010  COMPLETE
# 3                    1.0              0.00010  COMPLETE
# 4                    1.0              0.00000  COMPLETE
# 5                    1.0              0.00001  COMPLETE
# 6                    1.0              0.00001  COMPLETE
# 7                    1.0              0.00001  COMPLETE
# 8                    1.0              0.00000  COMPLETE
# 9                    1.0              0.00001  COMPLETE
# 10                   1.0              0.00000  COMPLETE
# 11                   1.0              0.00000  COMPLETE
# 12                   1.0              0.00000  COMPLETE
# 13                   1.0              0.00000  COMPLETE
# 14                   1.0              0.00000  COMPLETE
# 15                   1.0              0.00000  COMPLETE
# 16                   1.0              0.00000  COMPLETE
# 17                   1.0              0.00010  COMPLETE
# 18                   1.0              0.00000  COMPLETE
# 19                   1.0              0.00000  COMPLETE
# 20                   1.0              0.00010  COMPLETE
# 21                   1.0              0.00000  COMPLETE
# 22                   1.0              0.00000  COMPLETE
# 23                   1.0              0.00000  COMPLETE
# 24                   1.0              0.00000  COMPLETE
# 25                   1.0              0.00000  COMPLETE
# 26                   1.0              0.00000  COMPLETE
# 27                   1.0              0.00000  COMPLETE
# 28                   1.0              0.00000  COMPLETE
# 29                   1.0              0.00010  COMPLETE
# 30                   1.0              0.00000  COMPLETE
# 31                   1.0              0.00000  COMPLETE
# 32                   1.0              0.00000  COMPLETE
# 33                   1.0              0.00000  COMPLETE
# 34                   1.0              0.00000  COMPLETE
# 35                   1.0              0.00010  COMPLETE
# 36                   1.0              0.00001  COMPLETE
# 37                   1.0              0.00000  COMPLETE
# 38                   1.0              0.00001  COMPLETE
# 39                   1.0              0.00000  COMPLETE
# 40                   1.0              0.00001      FAIL
#
# [41 rows x 22 columns]
# best_value: 0.0014421445372780894
# best_params: {'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 16, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}
# best_trial: FrozenTrial(number=4, values=[0.0014421445372780894], datetime_start=datetime.datetime(2022, 9, 5, 19, 52, 55, 838767), datetime_complete=datetime.datetime(2022, 9, 5, 21, 13, 9, 481348), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 16, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=5, state=TrialState.COMPLETE, value=None)
#
#
# total: 41trias
# above: best trials, the later the better..
# FrozenTrial(number=40, values=None, datetime_start=datetime.datetime(2022, 9, 8, 10, 42, 36, 309010), datetime_complete=datetime.datetime(2022, 9, 8, 11, 34, 52, 169064), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 1e-05}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=41, state=TrialState.FAIL, value=None)
# FrozenTrial(number=17, values=[0.0017503044614736174], datetime_start=datetime.datetime(2022, 9, 6, 23, 18, 20, 16050), datetime_complete=datetime.datetime(2022, 9, 7, 0, 36, 50, 654460), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 1e-05, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0001}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=18, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=29, values=[0.001746019057804915], datetime_start=datetime.datetime(2022, 9, 7, 13, 42, 36, 996216), datetime_complete=datetime.datetime(2022, 9, 7, 14, 57, 30, 547698), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.2, 'ff_dim': 32, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 1e-05, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0001}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=30, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=14, values=[0.0017242482991750574], datetime_start=datetime.datetime(2022, 9, 6, 19, 27, 26, 389951), datetime_complete=datetime.datetime(2022, 9, 6, 20, 44, 52, 809910), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 1e-05, 'mlp_activation': 'relu', 'mlp_units': 32, 'num_heads': 2, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=15, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=25, values=[0.0017117358284557405], datetime_start=datetime.datetime(2022, 9, 7, 9, 3, 33, 38773), datetime_complete=datetime.datetime(2022, 9, 7, 10, 18, 16, 13822), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 1e-05, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=26, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=26, values=[0.0016615140754354663], datetime_start=datetime.datetime(2022, 9, 7, 10, 18, 16, 115645), datetime_complete=datetime.datetime(2022, 9, 7, 11, 17, 5, 632936), params={'activation': 'B2Bsqrt', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 32, 'head_size': 32, 'ifNorm': False, 'ifPE': False, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 16, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'adam', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=27, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=7, values=[0.0016546619695315679], datetime_start=datetime.datetime(2022, 9, 6, 5, 16, 8, 363042), datetime_complete=datetime.datetime(2022, 9, 6, 9, 21, 49, 631820), params={'activation': 'B2Bsqrt', 'alpha': 1.0, 'dropout': 0.0, 'ff_dim': 16, 'head_size': 32, 'ifNorm': True, 'ifPE': True, 'learning_rate': 1e-05, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'adam', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 1e-05}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=8, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=18, values=[0.0016316881198983335], datetime_start=datetime.datetime(2022, 9, 7, 0, 36, 50, 747449), datetime_complete=datetime.datetime(2022, 9, 7, 1, 36, 1, 870963), params={'activation': 'B2Bsqrt', 'alpha': 1.0, 'dropout': 0.0, 'ff_dim': 32, 'head_size': 32, 'ifNorm': False, 'ifPE': False, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 16, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'adam', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=19, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=35, values=[0.0015641642319751403], datetime_start=datetime.datetime(2022, 9, 7, 21, 13, 0, 784994), datetime_complete=datetime.datetime(2022, 9, 8, 1, 5, 3, 297883), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': True, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 2, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0001}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=36, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=2, values=[0.001551823631399163], datetime_start=datetime.datetime(2022, 9, 5, 11, 58, 29, 569132), datetime_complete=datetime.datetime(2022, 9, 5, 15, 49, 11, 123145), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.2, 'ff_dim': 16, 'head_size': 16, 'ifNorm': True, 'ifPE': False, 'learning_rate': 0.001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 2, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0001}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=3, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=39, values=[0.0015435965643486593], datetime_start=datetime.datetime(2022, 9, 8, 9, 43, 4, 743472), datetime_complete=datetime.datetime(2022, 9, 8, 10, 42, 36, 213901), params={'activation': 'B2Bsqrt', 'alpha': 1.0, 'dropout': 0.2, 'ff_dim': 32, 'head_size': 32, 'ifNorm': False, 'ifPE': False, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 16, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=40, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=3, values=[0.0015435965643486593], datetime_start=datetime.datetime(2022, 9, 5, 15, 49, 11, 208603), datetime_complete=datetime.datetime(2022, 9, 5, 19, 52, 55, 744350), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': True, 'ifPE': True, 'learning_rate': 0.001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 1, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0001}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=4, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=20, values=[0.0015398267711099756], datetime_start=datetime.datetime(2022, 9, 7, 2, 51, 53, 2253), datetime_complete=datetime.datetime(2022, 9, 7, 4, 9, 20, 52566), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0001}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=21, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=22, values=[0.0015232007668655179], datetime_start=datetime.datetime(2022, 9, 7, 5, 24, 20, 879353), datetime_complete=datetime.datetime(2022, 9, 7, 6, 36, 15, 676544), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 1, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=23, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=19, values=[0.0015228570265787278], datetime_start=datetime.datetime(2022, 9, 7, 1, 36, 1, 953874), datetime_complete=datetime.datetime(2022, 9, 7, 2, 51, 52, 884244), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.2, 'ff_dim': 16, 'head_size': 16, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=20, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=15, values=[0.0015202903243437538], datetime_start=datetime.datetime(2022, 9, 6, 20, 44, 52, 910431), datetime_complete=datetime.datetime(2022, 9, 6, 21, 59, 21, 320818), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'relu', 'mlp_units': 16, 'num_heads': 1, 'num_transformer_blocks': 1, 'optimizer': 'adam', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=16, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=23, values=[0.0015189153631968155], datetime_start=datetime.datetime(2022, 9, 7, 6, 36, 15, 795118), datetime_complete=datetime.datetime(2022, 9, 7, 7, 48, 35, 942409), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'relu', 'mlp_units': 32, 'num_heads': 2, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=24, state=TrialState.COMPLETE, value=None)
# ...
# FrozenTrial(number=21, values=[0.001490464368806399], datetime_start=datetime.datetime(2022, 9, 7, 4, 9, 20, 142219), datetime_complete=datetime.datetime(2022, 9, 7, 5, 24, 20, 767376), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'relu', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=22, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=11, values=[0.0014868664457111658], datetime_start=datetime.datetime(2022, 9, 6, 15, 32, 50, 576197), datetime_complete=datetime.datetime(2022, 9, 6, 16, 50, 43, 585385), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'relu', 'mlp_units': 32, 'num_heads': 1, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=12, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=34, values=[0.0014767601569988242], datetime_start=datetime.datetime(2022, 9, 7, 19, 57, 54, 153027), datetime_complete=datetime.datetime(2022, 9, 7, 21, 13, 0, 697419), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=35, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=32, values=[0.0014637320758495997], datetime_start=datetime.datetime(2022, 9, 7, 17, 27, 50, 486338), datetime_complete=datetime.datetime(2022, 9, 7, 18, 43, 4, 956004), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=33, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=33, values=[0.0014611653736145147], datetime_start=datetime.datetime(2022, 9, 7, 18, 43, 5, 56455), datetime_complete=datetime.datetime(2022, 9, 7, 19, 57, 54, 61956), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=34, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=24, values=[0.0014568799699458124], datetime_start=datetime.datetime(2022, 9, 7, 7, 48, 36, 30699), datetime_complete=datetime.datetime(2022, 9, 7, 9, 3, 32, 934500), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=25, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=16, values=[0.0014534539169939187], datetime_start=datetime.datetime(2022, 9, 6, 21, 59, 21, 429712), datetime_complete=datetime.datetime(2022, 9, 6, 23, 18, 19, 920818), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=17, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=27, values=[0.0014491685133251053], datetime_start=datetime.datetime(2022, 9, 7, 11, 17, 5, 724738), datetime_complete=datetime.datetime(2022, 9, 7, 12, 31, 22, 815222), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 32, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=28, state=TrialState.COMPLETE, value=None)
# FrozenTrial(number=4, values=[0.0014421445372780894], datetime_start=datetime.datetime(2022, 9, 5, 19, 52, 55, 838767), datetime_complete=datetime.datetime(2022, 9, 5, 21, 13, 9, 481348), params={'activation': 'relu', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 16, 'head_size': 16, 'ifNorm': False, 'ifPE': True, 'learning_rate': 0.0001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 3, 'num_transformer_blocks': 1, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2)), 'ff_dim': CategoricalDistribution(choices=(16, 32)), 'head_size': CategoricalDistribution(choices=(16, 32, 32)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3)), 'num_transformer_blocks': CategoricalDistribution(choices=(1,)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=5, state=TrialState.COMPLETE, value=None)

# %%
study.best_trial
# Out:
# FrozenTrial(number=98, values=[0.00603773584907541], datetime_start=datetime.datetime(2022, 9, 9, 21, 0, 44, 980881), datetime_complete=datetime.datetime(2022, 9, 9, 22, 0, 34, 65613), params={'activation': 'B2Bsqrt', 'alpha': 1.0, 'dropout': 0.1, 'ff_dim': 64, 'head_size': 16, 'ifNorm': False, 'ifPE': False, 'learning_rate': 0.001, 'mlp_activation': 'B2Bsqrt', 'mlp_units': 32, 'num_heads': 1, 'num_transformer_blocks': 2, 'optimizer': 'rmsprop', 'order_sprt': 9, 'param_llr_loss': 1.0, 'weight_decay': 0.0}, distributions={'activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'alpha': CategoricalDistribution(choices=(1.0,)), 'dropout': CategoricalDistribution(choices=(0.0, 0.1, 0.2, 0.3)), 'ff_dim': CategoricalDistribution(choices=(16, 32, 64, 128)), 'head_size': CategoricalDistribution(choices=(16, 32, 64, 128)), 'ifNorm': CategoricalDistribution(choices=(True, False)), 'ifPE': CategoricalDistribution(choices=(True, False)), 'learning_rate': CategoricalDistribution(choices=(0.001, 0.0001, 1e-05)), 'mlp_activation': CategoricalDistribution(choices=('relu', 'B2Bsqrt')), 'mlp_units': CategoricalDistribution(choices=(16, 32, 64, 128)), 'num_heads': CategoricalDistribution(choices=(1, 2, 3, 4)), 'num_transformer_blocks': CategoricalDistribution(choices=(1, 2)), 'optimizer': CategoricalDistribution(choices=('adam', 'rmsprop')), 'order_sprt': CategoricalDistribution(choices=(9,)), 'param_llr_loss': CategoricalDistribution(choices=(1.0,)), 'weight_decay': CategoricalDistribution(choices=(0.0, 1e-05, 0.0001, 0.001))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=99, state=TrialState.COMPLETE, value=None)

# %% [markdown]
# # Manually extract the tuning results

# %%
targdir = '/raid6/ebihara/tensorflow/logs/UCF2class/ckptlogs/Tfmr_UCF2class_tuning/'

best = 0.0
targtrial = ''
for trial in os.listdir(targdir):
    for result in os.listdir(targdir + trial):
        if 'macrec' and 'index' in result:
            value = float(result[result.find('macrec') + len('macrec') : result.find('-')])
            if value > best:
                best = value
                targtrial = trial
            elif value == best:
                raise ValueError('Exactly the same result!')

print(targtrial, best)
# Out:
# Tfmr_UCF2class_20220909_210045464 0.99396

# %%
1-0.0014421445372780894
# Out:
# 0.9985578554627219
