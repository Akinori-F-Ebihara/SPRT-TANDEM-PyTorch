# %%
import sys, pdb
import numpy as np
from loguru import logger
import matplotlib.pyplot as plt
import matplotlib
from jupyterthemes import jtplot
from scipy.stats import multivariate_normal, uniform
sys.path.append('/Users/AFE/Dropbox/PYTHON/SPRTproject/UrgingMAUS/')
from utils.misc import extract_params_from_config
from utils.logging import plot_example_trajectories, plot_likelihood_ratio_matrix
from datasets.data_processing import generate_likelihood_ratio_matrix
jtplot.reset()

######## USER MODIFIABLE BLOCKS ########
config = {
    'FEAT_DIM' : 128, # dimension of multivariate Gaussian
    'DENSITY_OFFSET' : 2.0, # separation of distributions
    'BATCH_SIZE' : 1000, # number of sequence that created at once
    'NUM_ITER' : 10, # total data number is batch_size * num_iter
    'TIME_STEPS' : 50, # length of time steps
    'NUM_CLASSES' : 3, # class numbers
    'IS_SHUFFLE': True, # shuffle data or not
    'ROOT_SAVEDIR' : '/Users/AFE/Dropbox/PYTHON/data/SDRE_data/',
}
######## USER MODIFIABLE BLOCKS END ########

assert config['FEAT_DIM'] > config['NUM_CLASSES']

# check if necessary parameters are defined in the config file
requirements = set(['FEAT_DIM', 'DENSITY_OFFSET', 'BATCH_SIZE',
                    'NUM_ITER', 'TIME_STEPS', 'NUM_CLASSES',
                    'ROOT_SAVEDIR', 'IS_SHUFFLE'])
conf = extract_params_from_config(requirements, config)
# Out:
# 2023-02-27 03:58:15.544906: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-27 03:58:15.544977: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Start generating SDRE data

# %%
x_iter_pool, y_iter_pool, llrm_iter_pool = generate_likelihood_ratio_matrix(conf)
# Out:
# 2023-02-27 03:58:27.432 | INFO     | datasets.data_processing:generate_likelihood_ratio_matrix:141 - Starting iter_i=0 / 9
# 2023-02-27 03:58:28.256 | INFO     | datasets.data_processing:generate_likelihood_ratio_matrix:141 - Starting iter_i=1 / 9
# 2023-02-27 03:58:30.866 | INFO     | datasets.data_processing:generate_likelihood_ratio_matrix:141 - Starting iter_i=2 / 9
# 2023-02-27 03:58:32.029 | INFO     | datasets.data_processing:generate_likelihood_ratio_matrix:141 - Starting iter_i=3 / 9
# 2023-02-27 03:58:32.960 | INFO     | datasets.data_processing:generate_likelihood_ratio_matrix:141 - Starting iter_i=4 / 9
# 2023-02-27 03:58:33.874 | INFO     | datasets.data_processing:generate_likelihood_ratio_matrix:141 - Starting iter_i=5 / 9
# 2023-02-27 03:58:34.809 | INFO     | datasets.data_processing:generate_likelihood_ratio_matrix:141 - Starting iter_i=6 / 9
# 2023-02-27 03:58:35.726 | INFO     | datasets.data_processing:generate_likelihood_ratio_matrix:141 - Starting iter_i=7 / 9
# 2023-02-27 03:58:36.748 | INFO     | datasets.data_processing:generate_likelihood_ratio_matrix:141 - Starting iter_i=8 / 9
# 2023-02-27 03:58:37.687 | INFO     | datasets.data_processing:generate_likelihood_ratio_matrix:141 - Starting iter_i=9 / 9
# 2023-02-27 03:58:39.179 | SUCCESS  | datasets.data_processing:generate_likelihood_ratio_matrix:184 - successfully generated SDRE data!
# 2023-02-27 03:58:39.201 | INFO     | datasets.data_processing:generate_likelihood_ratio_matrix:190 - shuffling the data...
# 2023-02-27 03:58:39.467 | SUCCESS  | datasets.data_processing:generate_likelihood_ratio_matrix:198 - done and dusted!

# %% [markdown]
# # Save the data

# %%
total_data = conf.num_iter * conf.num_classes * conf.batch_size
data_suffix = f'_{total_data}_{conf.num_classes}class_offset{conf.density_offset}'

logger.info('saving the data...')
np.save(f'{conf.root_savedir}x_batch{data_suffix}.npy', x_iter_pool)
np.save(f'{conf.root_savedir}y_batch{data_suffix}.npy', y_iter_pool)
np.save(f'{conf.root_savedir}gt_llrms{data_suffix}.npy', llrm_iter_pool)
logger.success('All done, well done!')
# Out:
# 2023-02-27 00:40:12.444 | INFO     | __main__:<cell line: 4>:4 - saving the data...
# 2023-02-27 00:40:15.278 | SUCCESS  | __main__:<cell line: 8>:8 - All done, well done!

# %% [markdown]
# # Sanity check

# %%
matplotlib.rcParams.update({'font.size': 22})

num_panels = conf.num_classes **2
num_trajectories = 100

jtplot.reset()

plt.figure(figsize=(18, 18))
plot_likelihood_ratio_matrix(llrm_iter_pool, y_iter_pool)
plt.show()

# %%
matplotlib.rcParams.update({'font.size': 12})

plt.figure(figsize=(16.2, 5))

plt.subplot(1,2,1)
plt.title('Ground-truth LLR trajectories')
dice = plot_example_trajectories(llrm_iter_pool, y_iter_pool)

plt.subplot(1,2,2)
plt.title('Estimated LLR trajectories')
_ = plot_example_trajectories(llrm_iter_pool, y_iter_pool, dice=dice)
# Out:
# dice[1]=range(0, 2)

# %%
aesthetic_num_traj = np.max([1, 20 // conf.num_classes])

plt.figure(figsize=(16.2, 5))

plt.subplot(1,2,1)
plt.title('Ground-truth LLR trajectories')
dice = plot_example_trajectories(llrm_iter_pool, y_iter_pool, dice=[None, None], max_traj_per_cls_pair=aesthetic_num_traj, max_example_cls=2)

plt.subplot(1,2,2)
plt.title('Estimated LLR trajectories')
_ = plot_example_trajectories(llrm_iter_pool, y_iter_pool, dice=dice, max_traj_per_cls_pair=aesthetic_num_traj, max_example_cls=2)
# Out:
# dice[1]=range(0, 2)
